# %% [markdown]
# <a href="https://colab.research.google.com/github/Adriana-Correa-de-Lima/Adriana-Correa-de-Lima/blob/main/Treinando_Aula_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
""" Leia dois valores inteiros e armazene-os nas variáveis A e B. Efetue a soma de A e B
atribuindo o seu resultado na variável X. Imprima X conforme exemplo apresentado
abaixo. Não apresente mensagem alguma além daquilo que está sendo especificado e não
esqueça de imprimir a quebra de linha após o resultado.   """

A = int(input( ))
B = int(input( ))

print ("X =", A + B)
# Out:
# 3
# 5
# X = 8
